# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace, function_tool
from openai.types.responses import ResponseTextDeltaEvent
from typing import Dict
import sendgrid
import os
from sendgrid.helpers.mail import Mail, Email, To, Content
import asyncio

# %%
agent = Agent(name = "Jokester", instructions="You are a Joke teller", model="gpt-4o-mini")

# %%
result = await Runner.run(agent, "Tell me a joke about women")

# %%
print(result.final_output)
# Out:
# Sure, here's a light-hearted joke:
#
# Why did the woman bring a ladder to the bar?
#
# Because she heard the drinks were on the house!

# %%
instructions1 = "You are a sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write professional, serious cold emails."

instructions2 = "You are a humorous, engaging sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write witty, engaging cold emails that are likely to get a response."

instructions3 = "You are a busy sales agent working for ComplAI, \
a company that provides a SaaS tool for ensuring SOC2 compliance and preparing for audits, powered by AI. \
You write concise, to the point cold emails."

# %%
sales_agent1 = Agent(
    name = "Professional Sales Agent",
    instructions=instructions1,
    model = "gpt-4o-mini"
)

sales_agent2 = Agent(
    name = "Engineering Sales Agent",
    instructions=instructions2,
    model = "gpt-4o-mini"
)

sales_agent3 = Agent(
    name = "Busy Sales Agent",
    instructions=instructions3,
    model = "gpt-4o-mini"
)

# %%
result = await Runner.run(sales_agent1, "Write a Cold sales Email")
print(result.final_output)
# Out:
# Subject: Simplify Your SOC 2 Compliance Journey with ComplAI
#
# Hi [Recipient's Name],
#
# I hope this message finds you well. I’m [Your Name], reaching out on behalf of ComplAI, where we leverage AI technology to streamline SOC 2 compliance and audit preparation.
#
# In today's regulatory environment, ensuring robust security measures is crucial. However, the complexities of compliance can be overwhelming and time-consuming. ComplAI is designed to simplify this process, offering smart automation and actionable insights tailored to your organization’s needs.
#
# Here’s how ComplAI can benefit your team:
#
# - **Automated Documentation**: Say goodbye to manual documentation efforts. Our tool automates the documentation process, reducing errors and saving valuable time.
# - **Continuous Monitoring**: Stay ahead of compliance requirements with real-time monitoring and alerts, ensuring you never miss critical updates.
# - **Seamless Collaboration**: Easily involve your entire team in compliance efforts with user-friendly interfaces that foster collaboration.
#
# I would love to schedule a brief call to discuss how ComplAI can support your compliance initiatives and help your organization thrive. Could we set aside 15 minutes this week?
#
# Thank you for considering ComplAI as your compliance partner. I look forward to the opportunity to connect.
#
# Best regards,
#
# [Your Name]
# [Your Job Title]
# ComplAI
# [Your Phone Number]
# [Your Email Address]
# [Website URL]
